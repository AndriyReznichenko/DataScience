# %%
import numpy as np
import pandas as pd
from collections import defaultdict 
import random
import math

pd.set_option('max_columns', None)

import collections
compare = lambda x, y: collections.Counter(x) == collections.Counter(y)

# %%
df_food = pd.read_csv('data/food_data.csv')
cols = [4, 8, 9]
df_food.drop(columns = df_food.columns[cols], axis=1, inplace=True)
#df_food.sort_values(by=df_food.columns[2])
df_food[df_food.columns[2:]] = df_food[df_food.columns[2:]] * 100

cols=['Calcium (g)', 'Phosphorus (g)','Potassium (g)','Sodium (g)']
df_food[cols] = df_food[cols] / 100

cols=['Phosphorus (g)','Potassium (g)','Sodium (g)']
df_food[cols] = df_food[cols] / 10

df_food = df_food.iloc[:,[0,1,2,9,10,11]]

df_food
# Out:
#              name emoji  Calories (kcal)  Vitamin B6 (mg)  Vitamin A (IU)  \
# 0          grapes     🍇             69.0            0.086            66.0
# 1           melon     🍈             28.0            0.163             0.0
# 2      watermelon     🍉             30.0            0.045           569.0
# 3       tangerine     🍊             53.0            0.078           681.0
# 4           lemon     🍋             29.0            0.080            22.0
# 5          banana     🍌             89.0            0.367            64.0
# 6       pineapple     🍍             50.0            0.112            58.0
# 7       red apple     🍎             63.0            0.045            38.0
# 8     green apple     🍏             58.0            0.037           100.0
# 9            pear     🍐             57.0            0.029            25.0
# 10          peach     🍑             39.0            0.025           326.0
# 11       cherries     🍒             63.0            0.049            64.0
# 12     strawberry     🍓             32.0            0.047            12.0
# 13      kiwifruit     🥝             61.0            0.063            87.0
# 14         tomato     🍅             18.0            0.080           833.0
# 15        avocado     🥑            160.0            0.257           146.0
# 16       eggplant     🍆             25.0            0.084            23.0
# 17         potato     🥔             90.0            0.286         19218.0
# 18         carrot     🥕             41.0            0.138         16706.0
# 19           corn     🌽             96.0            0.139           263.0
# 20     hot pepper     🌶             40.0            0.506           952.0
# 21       cucumber     🥒             15.0            0.040           105.0
# 22       mushroom     🍄             22.0            0.104             0.0
# 23        peanuts     🥜            567.0            0.348             0.0
# 24       chestnut     🌰            196.0            0.352            26.0
# 25          bread     🍞            274.0            0.111             2.0
# 26      croissant     🥐            406.0            0.058           744.0
# 27   french bread     🥖            272.0            0.107             1.0
# 28       pancakes     🥞            227.0            0.046           196.0
# 29         cheese     🧀            393.0            0.071          1047.0
# 30           beef     🍖            217.0            0.758             5.0
# 31        chicken     🍗            184.0            0.413            68.0
# 32          bacon     🥓            898.0            0.005            37.0
# 33      hamburger     🍔            254.0            0.110            75.0
# 34   french fries     🍟            312.0            0.372             0.0
# 35          pizza     🍕            266.0            0.080           358.0
# 36         hotdog     🌭            247.0            0.050             0.0
# 37           taco     🌮            226.0            0.090           131.0
# 38        burrito     🌯            180.0            0.097           277.0
# 39        popcorn     🍿            500.0            0.209            11.0
# 40  rice crackers     🍘            416.0            0.554             0.0
# 41           rice     🍚            130.0            0.050             0.0
# 42      spaghetti     🍝            157.0            0.049             0.0
# 43   fried shrimp     🍤            308.0            0.060           109.0
# 44      ice cream     🍨            222.0            0.048           589.0
# 45       doughnut     🍩            417.0            0.027            39.0
# 46         cookie     🍪            497.0            0.017             4.0
# 47           cake     🍰            371.0            0.041           140.0
# 48  chocolate bar     🍫            518.0            0.020            81.0
# 49          candy     🍬            394.0            0.003             0.0
# 50   custard flan     🍮            145.0            0.044           161.0
# 51          honey     🍯            304.0            0.024             0.0
# 52           milk     🥛             64.0            0.042           138.0
# 53      black tea     🍵              1.0            0.000             0.0
# 54           sake     🍶            134.0            0.000             0.0
# 55      champagne     🍾             84.0            0.050             0.0
# 56       red wine     🍷             85.0            0.057             2.0
# 57           beer     🍺             43.0            0.046             0.0
# 58          dummy     🍺            400.0            0.000             0.0
#
#     Vitamin B12 (ug)
# 0               0.00
# 1               0.00
# 2               0.00
# 3               0.00
# 4               0.00
# 5               0.00
# 6               0.00
# 7               0.00
# 8               0.00
# 9               0.00
# 10              0.00
# 11              0.00
# 12              0.00
# 13              0.00
# 14              0.00
# 15              0.00
# 16              0.00
# 17              0.00
# 18              0.00
# 19              0.00
# 20              0.00
# 21              0.00
# 22              0.04
# 23              0.00
# 24              0.00
# 25              0.00
# 26              0.16
# 27              0.00
# 28              0.22
# 29              3.06
# 30              1.89
# 31              0.38
# 32              0.09
# 33              0.80
# 34              0.00
# 35              0.42
# 36              0.52
# 37              0.93
# 38              0.27
# 39              0.00
# 40              0.00
# 41              0.00
# 42              0.00
# 43              0.53
# 44              0.50
# 45              0.10
# 46              0.00
# 47              0.16
# 48              0.56
# 49              0.00
# 50              0.36
# 51              0.00
# 52              0.36
# 53              0.00
# 54              0.00
# 55              0.00
# 56              0.00
# 57              0.02
# 58              0.00

# %%
min_rdi = pd.read_csv('data/min_rdi.csv')
min_rdi = min_rdi.iloc[:,[0,7,8,9]]
min_rdi.head()
# Out:
#    Calories (kcal)  Vitamin B6 (mg)  Vitamin A (IU)  Vitamin B12 (ug)
# 0             2000              1.3            3000               2.4

# %%
prod_list = ['cheese', 'beef', 'milk', 'mushroom', 'rice']
products = df_food[df_food['name'].isin(prod_list)]
np_products = products.to_numpy()

products.head(25)
# Out:
#         name emoji  Calories (kcal)  Vitamin B6 (mg)  Vitamin A (IU)  \
# 22  mushroom     🍄             22.0            0.104             0.0
# 29    cheese     🧀            393.0            0.071          1047.0
# 30      beef     🍖            217.0            0.758             5.0
# 41      rice     🍚            130.0            0.050             0.0
# 52      milk     🥛             64.0            0.042           138.0
#
#     Vitamin B12 (ug)
# 22              0.04
# 29              3.06
# 30              1.89
# 41              0.00
# 52              0.36

# %%
class Branch:
    def __init__(self):
        self.nutritions = np.zeros(4)
        self.calories = 0
        self.history = []
        self.used = False
        self.fitness = 0
        self.entropy = 0

# %%
branches = []
branches.append(Branch())
print(branches[0].history)
print(branches[0].nutritions)
# Out:
# []
# [0. 0. 0. 0.]

# %%
drop_factor = 0.2
searched = []
new_branches = []
current_branches = []
current_branches.append(Branch())

i = 0

finished = False


while not finished:
    i +=1
    print(i)
    #print (all(nb.nutritions[2] < min_rdi.loc(0)[0][0] * 0.1  for nb in new_branches))
    new_branches = []
    for n in range(len(current_branches)):
        for j in range(len(np_products)):
            history_copy = current_branches[n].history.copy()
            history_copy.append(np_products[j][0])
            # if this combination of food doesn't exists
            # and this combination doesn't leads to 120% RDI of calories
            # and random drop factor (to speed up work)
            if (not any(compare(history_copy, item.history) for item in new_branches) 
                and (np_products[j][2] + current_branches[n].calories < min_rdi.loc(0)[0][0] * 1.2)
                and random.random() > drop_factor):
                new_branch = Branch()
                new_branch.calories = current_branches[n].calories + np_products[j][2]
                new_branch.history = current_branches[n].history.copy()
                new_branch.history.append(np_products[j][0])
                new_branches.append(new_branch)
                
    finished = not (any(len(nb.history) < 7 for nb in new_branches))
                
    searched.extend(current_branches)
    current_branches = new_branches
       
    
    
searched.extend(new_branches)

print('END')
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# END

# %%
branches = [s for s in searched if (min_rdi.loc(0)[0][0] * 0.8 
                             < s.calories
                             < min_rdi.loc(0)[0][0] * 1.2)]

# %%
for b in branches:
    for h in b.history:
        b.nutritions = b.nutritions + df_food[df_food['name'] == h].to_numpy()[0,2:]

# %%
len(branches)
# Out:
# 79

# %%
def normalize(b):
    b.nutritions = b.nutritions.copy() / min_rdi.loc(0)[0]
    return b

# %%
branches = list(map(normalize, branches))

# %%
entropy_coef = 1
eps = 0.01
for b in branches:
    val_sum = sum(collections.Counter(b.history).values())
    b.entropy = - sum([i / val_sum * math.log(i / val_sum, 2) 
                     for i in list(collections.Counter(b.history).values())])
    
    #fitness = 1 / SUM(SE) * entropy
    fit = 1 / (sum([min(s, 0) ** 2 for s in b.nutritions - 1]) + eps)
    b.fitness = fit - fit * (1 - b.entropy) * entropy_coef

# %%
branches.sort(key = lambda b: b.fitness, reverse = True)

# %%
print('BEST DIETS')
for i in range(min(10, len(branches))):
    print(branches[i].history)
    print(branches[i].fitness)
    print(branches[i].entropy)
    print('---------------------------')
# Out:
# BEST DIETS
# ['cheese', 'cheese', 'cheese', 'beef', 'rice', 'beef', 'beef']
# 139.3091957428062
# 1.4488156357251847
# ---------------------------
# ['mushroom', 'cheese', 'cheese', 'cheese', 'cheese', 'beef', 'beef']
# 137.87834934861758
# 1.3787834934861758
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'cheese', 'beef', 'rice', 'beef']
# 137.87834934861755
# 1.3787834934861756
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'cheese', 'beef', 'beef', 'milk']
# 137.87834934861755
# 1.3787834934861756
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'beef', 'milk', 'beef', 'beef']
# 113.10919164065768
# 1.4488156357251847
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'beef', 'rice', 'beef', 'rice']
# 110.93421991931606
# 1.5566567074628228
# ---------------------------
# ['cheese', 'cheese', 'beef', 'beef', 'cheese', 'beef', 'beef']
# 98.52281360342516
# 0.9852281360342516
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'cheese', 'beef', 'beef', 'beef']
# 98.52281360342516
# 0.9852281360342516
# ---------------------------
# ['mushroom', 'cheese', 'cheese', 'cheese', 'cheese', 'beef', 'rice']
# 96.37948374809054
# 1.6644977792004616
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'beef', 'rice', 'beef', 'milk']
# 95.39908571901816
# 1.8423709931771088
# ---------------------------

# %%
print('WORST DIETS')
for i in range(min(10, len(branches)), -1, -1):
    print(branches[i].history)
    print(branches[i].fitness)
    print(branches[i].entropy)
    print('---------------------------')
# Out:
# WORST DIETS
# ['mushroom', 'cheese', 'beef', 'beef', 'cheese', 'beef', 'cheese']
# 93.61693174755655
# 1.4488156357251847
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'beef', 'rice', 'beef', 'milk']
# 95.39908571901816
# 1.8423709931771088
# ---------------------------
# ['mushroom', 'cheese', 'cheese', 'cheese', 'cheese', 'beef', 'rice']
# 96.37948374809054
# 1.6644977792004616
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'cheese', 'beef', 'beef', 'beef']
# 98.52281360342516
# 0.9852281360342516
# ---------------------------
# ['cheese', 'cheese', 'beef', 'beef', 'cheese', 'beef', 'beef']
# 98.52281360342516
# 0.9852281360342516
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'beef', 'rice', 'beef', 'rice']
# 110.93421991931606
# 1.5566567074628228
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'beef', 'milk', 'beef', 'beef']
# 113.10919164065768
# 1.4488156357251847
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'cheese', 'beef', 'beef', 'milk']
# 137.87834934861755
# 1.3787834934861756
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'cheese', 'beef', 'rice', 'beef']
# 137.87834934861755
# 1.3787834934861756
# ---------------------------
# ['mushroom', 'cheese', 'cheese', 'cheese', 'cheese', 'beef', 'beef']
# 137.87834934861758
# 1.3787834934861758
# ---------------------------
# ['cheese', 'cheese', 'cheese', 'beef', 'rice', 'beef', 'beef']
# 139.3091957428062
# 1.4488156357251847
# ---------------------------

# %%
branches[-1].nutritions
# Out:
# Calories (kcal)       0.9825
# Vitamin B6 (mg)     0.273077
# Vitamin A (IU)         1.745
# Vitamin B12 (ug)       6.375
# Name: 0, dtype: object

# %%
branches[0].nutritions
# Out:
# Calories (kcal)         0.98
# Vitamin B6 (mg)     1.951538
# Vitamin A (IU)         1.052
# Vitamin B12 (ug)      6.1875
# Name: 0, dtype: object

# %%
collections.Counter(branches[0].history)
# Out:
# Counter({'cheese': 3, 'beef': 3, 'rice': 1})
